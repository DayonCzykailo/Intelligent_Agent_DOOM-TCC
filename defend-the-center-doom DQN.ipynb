# %%
#pip install vizdoom

# %%
# !cd github & git clone https://github.com/Farama-Foundation/ViZDoom

# %%
# Import vizdoom for game env
from vizdoom import *
# Import random for action sampling
import random
# Import time for sleeping
import time
# Import numpy for identity matrix
import numpy as np

# %%
# Setup game
game = DoomGame()
game.load_config('scenarios/defend_the_center.cfg')
game.init()

# %%
# This is the set of actions we can take in the environment
actions = np.identity(3, dtype=np.uint8)

# %%
state = game.get_state()

# %%
state.game_variables
# Out:
# array([ 26., 100.])

# %%
# # Loop through episodes
# episodes = 10
# for episode in range(episodes):
#     # Create a new episode or game
#     game.new_episode()
#     # Check the game isn't done
#     while not game.is_episode_finished():
#         # Get the game state
#         state = game.get_state()
#         # Get the game image
#         img = state.screen_buffer
#         # Get the game variables - ammo
#         info = state.game_variables
#         # Take an action
#         reward = game.make_action(random.choice(actions), 4)
#         # Print reward
#         print('reward: ', reward)
#         time.sleep(0.02)
#     print('Result: ', game.get_total_reward())
#     time.sleep(2)

# %%
game.close()

# %% [markdown]
# ## 2. Converting it to a Gym Environment

# %%
# !pip install gym

# %%
# !pip install opencv-python

# %%
# Import environment base class from OpenAI Gym
from gym import Env
# Import gym spaces
from gym.spaces import Discrete, Box
# Import opencv
import cv2
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
# Create Vizdoom OpenAI Gym Environment
class VizDoomGym(Env):
    # Function that is called when we start the env
    def __init__(self, render=False):
        # Inherit from Env
        super().__init__()
        # Setup the game
        self.game = DoomGame()
        self.game.load_config('scenarios/defend_the_center.cfg')

        # Render frame logic
        if render == False:
            self.game.set_window_visible(False)
        else:
            self.game.set_window_visible(True)

        # Start the game
        self.game.init()

        # Create the action space and observation space
        self.observation_space = Box(low=0, high=255, shape=(100, 160, 1), dtype=np.uint8)
        self.action_space = Discrete(3)

        self.last_health = 100
    
    # This is how we take a step in the environment
    def step(self, action):
        # Specify action and take step
        actions = np.identity(3)
        reward = self.game.make_action(actions[action], 4) # 4 here is the frameskip parameter which makes the game run faster

        # Get all the other stuff we need to return
        if self.game.get_state():
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            
            ammo, health = self.game.get_state().game_variables #[ 26. 100.]
            #print("ammo {} | health -> {} | last health {}".format(ammo, health, self.last_health))

            # if self.last_health != health: # this not make sense, because the IA always need lost health and its punish how many times it takes damage
            #     reward = -5

            self.last_health = health
            info = ammo

            
            
        else:
            state = np.zeros(self.observation_space.shape)
            info = 0

        info = {'info': info}
        done = self.game.is_episode_finished() 

        return state, reward, done, info
        
    # Define how to render the game or environment
    def render():
        pass

    # What happens when we start a new game
    def reset(self):
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)

    # Grayscale the game frame and resize it 
    def grayscale(self, observation):
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160,1))
        return state

    # Call to close down the game
    def close(self):
        self.game.close()

# %%
env = VizDoomGym(render=True)

# %%
state = env.reset()

# %%
env.step(2)
# Out:
# (array([[[ 5],
#          [10],
#          [ 7],
#          ...,
#          [ 4],
#          [ 6],
#          [10]],
#
#         [[ 3],
#          [ 3],
#          [ 4],
#          ...,
#          [ 5],
#          [ 3],
#          [ 7]],
#
#         [[11],
#          [ 7],
#          [10],
#          ...,
#          [ 9],
#          [ 6],
#          [ 6]],
#
#         ...,
#
#         [[75],
#          [63],
#          [62],
#          ...,
#          [44],
#          [71],
#          [60]],
#
#         [[15],
#          [48],
#          [47],
#          ...,
#          [49],
#          [69],
#          [47]],
#
#         [[22],
#          [14],
#          [26],
#          ...,
#          [57],
#          [37],
#          [39]]], shape=(100, 160, 1), dtype=uint8),
#  0.0,
#  False,
#  {'info': np.float64(26.0)})

# %%
# Import Environment checker
from stable_baselines3.common import env_checker
# Out:
# 2025-11-12 15:11:46.982001: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# env_checker.check_env(env)

# %% [markdown]
# ## 3. View State

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(cv2.cvtColor(state, cv2.COLOR_BGR2RGB))

# %%
env.close()

# %% [markdown]
# ## 4. Setup Callback

# %%
# !pip install stable-baselines3[extra]

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %%
# Import os for file nav
import os 
# Import callback class from sb3
from stable_baselines3.common.callbacks import BaseCallback
#import tensorflow as tf

# %%
class TrainAndLoggingCallback(BaseCallback):
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/dqn/defend_the_center'
LOG_DIR = './logs/dqn/defend_the_center'

#tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=LOG_DIR, histogram_freq=5)

# %%
# callback = [TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR), tensorboard_callback]
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# ## 5. Train Gym

# %%
# Import ppo for training 
from stable_baselines3 import DQN

# %%
# Non rendered environment
env = VizDoomGym()

# %%
#model = PPO('CnnPolicy', env, tensorboard_log=LOG_DIR, verbose=1, learning_rate=0.0001, n_steps=4096)

model = DQN(
    'CnnPolicy', 
    env, 
    tensorboard_log=LOG_DIR, 
    verbose=1, 
    learning_rate=0.0001,             # Keep the learning rate stable for gradual learning
    buffer_size=50000,                # Sufficient buffer size for storing experiences
    learning_starts=500,              # Start learning earlier for quicker adaptation
    batch_size=32,                    # Larger batch size for more robust updates
    tau=1.0,                          # Keep tau at 1.0 (hard target updates)
    gamma=0.95,                       # Standard discount for future rewards
    train_freq=4,                     # Train every 4 steps
    gradient_steps=1,                 # Single gradient step per training iteration
    target_update_interval=5000,      # Moderate update interval for more stable learning
    exploration_fraction=0.05,        # Increase exploration to 25% to encourage diverse actions
    exploration_initial_eps=1.0,      # Start fully random exploration
    exploration_final_eps=0.05,       # Slightly higher final exploration rate to keep some randomness
    max_grad_norm=10,                 # Gradient clipping to stabilize training
    optimize_memory_usage=False       # Disable to prevent memory and timeout conflict
)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# /home/dayon/Projetos/Intelligent_Agent_DOOM-TCC/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Logging to ./logs/dqn/defend_the_center/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.8     |
# |    ep_rew_mean      | 0.75     |
# |    exploration_rate | 0.946    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 220      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 283      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.8     |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 160      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 654      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.8e-05  |
# |    n_updates        | 38       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.2     |
# |    ep_rew_mean      | 0.417    |
# |    exploration_rate | 0.808    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 145      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 1010     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.017    |
# |    n_updates        | 127      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.3     |
# |    ep_rew_mean      | 0.5      |
# |    exploration_rate | 0.738    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 136      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 1381     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0142   |
# |    n_updates        | 220      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.5     |
# |    ep_rew_mean      | 0.4      |
# |    exploration_rate | 0.675    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 131      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 1710     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00941  |
# |    n_updates        | 302      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 85.6     |
# |    ep_rew_mean      | 0.583    |
# |    exploration_rate | 0.61     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 128      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 2054     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000446 |
# |    n_updates        | 388      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 86.1     |
# |    ep_rew_mean      | 0.607    |
# |    exploration_rate | 0.542    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 126      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 2411     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 477      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | 0.844    |
# |    exploration_rate | 0.452    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 124      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 2882     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000491 |
# |    n_updates        | 595      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.9     |
# |    ep_rew_mean      | 0.806    |
# |    exploration_rate | 0.398    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 124      |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 3166     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00097  |
# |    n_updates        | 666      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.5     |
# |    ep_rew_mean      | 0.95     |
# |    exploration_rate | 0.327    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 121      |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 3540     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0166   |
# |    n_updates        | 759      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.5     |
# |    ep_rew_mean      | 0.909    |
# |    exploration_rate | 0.268    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 122      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 3851     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0292   |
# |    n_updates        | 837      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.1     |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.196    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 121      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 4230     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0231   |
# |    n_updates        | 932      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.1     |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.12     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 119      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 4631     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000708 |
# |    n_updates        | 1032     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89       |
# |    ep_rew_mean      | 1.02     |
# |    exploration_rate | 0.0532   |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 117      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 4983     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00223  |
# |    n_updates        | 1120     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.1     |
# |    ep_rew_mean      | 0.983    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 117      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 5287     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00372  |
# |    n_updates        | 1196     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.2     |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 116      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 5647     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0229   |
# |    n_updates        | 1286     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.5     |
# |    ep_rew_mean      | 1.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 117      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 5951     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0028   |
# |    n_updates        | 1362     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.2     |
# |    ep_rew_mean      | 1.08     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 117      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 6347     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00439  |
# |    n_updates        | 1461     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.2     |
# |    ep_rew_mean      | 1.09     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 116      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 6704     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0307   |
# |    n_updates        | 1550     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.4     |
# |    ep_rew_mean      | 1.11     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 116      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 7071     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0323   |
# |    n_updates        | 1642     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88.3     |
# |    ep_rew_mean      | 1.14     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 116      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 7415     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00134  |
# |    n_updates        | 1728     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 87.9     |
# |    ep_rew_mean      | 1.15     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 115      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 7736     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0334   |
# |    n_updates        | 1808     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.1     |
# |    ep_rew_mean      | 1.25     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 114      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 8198     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00169  |
# |    n_updates        | 1924     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90       |
# |    ep_rew_mean      | 1.32     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 117      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 8638     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00292  |
# |    n_updates        | 2034     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.8     |
# |    ep_rew_mean      | 1.43     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 117      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 9084     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00146  |
# |    n_updates        | 2145     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 91.7     |
# |    ep_rew_mean      | 1.47     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 117      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 9448     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000979 |
# |    n_updates        | 2236     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 92.3     |
# |    ep_rew_mean      | 1.54     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 117      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 9880     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0123   |
# |    n_updates        | 2344     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.5     |
# |    ep_rew_mean      | 1.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 115      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 10363    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 2465     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 93.6     |
# |    ep_rew_mean      | 1.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 115      |
# |    time_elapsed     | 93       |
# |    total_timesteps  | 10743    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0165   |
# |    n_updates        | 2560     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.2     |
# |    ep_rew_mean      | 1.92     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 114      |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 11228    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0234   |
# |    n_updates        | 2681     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 95.3     |
# |    ep_rew_mean      | 1.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 114      |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 11587    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00262  |
# |    n_updates        | 2771     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 98.1     |
# |    ep_rew_mean      | 2.16     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 113      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 12220    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0129   |
# |    n_updates        | 2929     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 2.32     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 112      |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 12879    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00336  |
# |    n_updates        | 3094     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 101      |
# |    ep_rew_mean      | 2.39     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 112      |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 13250    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00606  |
# |    n_updates        | 3187     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 103      |
# |    ep_rew_mean      | 2.51     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 111      |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 13815    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00548  |
# |    n_updates        | 3328     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | 2.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 111      |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 14289    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 3447     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 104      |
# |    ep_rew_mean      | 2.69     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 110      |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 14660    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0168   |
# |    n_updates        | 3539     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | 2.82     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 110      |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 15191    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00575  |
# |    n_updates        | 3672     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 109      |
# |    ep_rew_mean      | 3.11     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 110      |
# |    time_elapsed     | 144      |
# |    total_timesteps  | 15856    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0132   |
# |    n_updates        | 3838     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 111      |
# |    ep_rew_mean      | 3.35     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 109      |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 16428    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00622  |
# |    n_updates        | 3981     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 3.53     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 109      |
# |    time_elapsed     | 153      |
# |    total_timesteps  | 16905    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0255   |
# |    n_updates        | 4101     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | 3.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 109      |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 17466    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0133   |
# |    n_updates        | 4241     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 116      |
# |    ep_rew_mean      | 3.82     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 109      |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 17902    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00385  |
# |    n_updates        | 4350     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 116      |
# |    ep_rew_mean      | 3.9      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 110      |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 18305    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0085   |
# |    n_updates        | 4451     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | 4.02     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 110      |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 18756    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00256  |
# |    n_updates        | 4563     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 118      |
# |    ep_rew_mean      | 4.15     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 111      |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 19222    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00931  |
# |    n_updates        | 4680     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 4.32     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 111      |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 19721    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00268  |
# |    n_updates        | 4805     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 121      |
# |    ep_rew_mean      | 4.47     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 111      |
# |    time_elapsed     | 182      |
# |    total_timesteps  | 20283    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00899  |
# |    n_updates        | 4945     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 122      |
# |    ep_rew_mean      | 4.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 110      |
# |    time_elapsed     | 188      |
# |    total_timesteps  | 20871    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00444  |
# |    n_updates        | 5092     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 124      |
# |    ep_rew_mean      | 4.86     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 110      |
# |    time_elapsed     | 193      |
# |    total_timesteps  | 21489    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00323  |
# |    n_updates        | 5247     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 127      |
# |    ep_rew_mean      | 5.17     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 110      |
# |    time_elapsed     | 200      |
# |    total_timesteps  | 22181    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0109   |
# |    n_updates        | 5420     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 129      |
# |    ep_rew_mean      | 5.43     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 110      |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 22755    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00301  |
# |    n_updates        | 5563     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | 5.55     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 110      |
# |    time_elapsed     | 210      |
# |    total_timesteps  | 23322    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0256   |
# |    n_updates        | 5705     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 5.88     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 110      |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 24153    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00781  |
# |    n_updates        | 5913     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | 6.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 110      |
# |    time_elapsed     | 223      |
# |    total_timesteps  | 24718    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00913  |
# |    n_updates        | 6054     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 136      |
# |    ep_rew_mean      | 6.13     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 110      |
# |    time_elapsed     | 228      |
# |    total_timesteps  | 25223    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0114   |
# |    n_updates        | 6180     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 138      |
# |    ep_rew_mean      | 6.34     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 111      |
# |    time_elapsed     | 232      |
# |    total_timesteps  | 26028    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00266  |
# |    n_updates        | 6381     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 138      |
# |    ep_rew_mean      | 6.39     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 113      |
# |    time_elapsed     | 235      |
# |    total_timesteps  | 26689    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00425  |
# |    n_updates        | 6547     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 140      |
# |    ep_rew_mean      | 6.54     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 113      |
# |    time_elapsed     | 239      |
# |    total_timesteps  | 27228    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00328  |
# |    n_updates        | 6681     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 139      |
# |    ep_rew_mean      | 6.48     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 114      |
# |    time_elapsed     | 241      |
# |    total_timesteps  | 27695    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0167   |
# |    n_updates        | 6798     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 140      |
# |    ep_rew_mean      | 6.57     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 115      |
# |    time_elapsed     | 245      |
# |    total_timesteps  | 28250    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 6937     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 141      |
# |    ep_rew_mean      | 6.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 114      |
# |    time_elapsed     | 250      |
# |    total_timesteps  | 28794    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0131   |
# |    n_updates        | 7073     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 141      |
# |    ep_rew_mean      | 6.85     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 115      |
# |    time_elapsed     | 253      |
# |    total_timesteps  | 29338    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00513  |
# |    n_updates        | 7209     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 139      |
# |    ep_rew_mean      | 6.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 115      |
# |    time_elapsed     | 257      |
# |    total_timesteps  | 29763    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00301  |
# |    n_updates        | 7315     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 138      |
# |    ep_rew_mean      | 6.7      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 115      |
# |    time_elapsed     | 262      |
# |    total_timesteps  | 30274    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00595  |
# |    n_updates        | 7443     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 140      |
# |    ep_rew_mean      | 6.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 115      |
# |    time_elapsed     | 268      |
# |    total_timesteps  | 30877    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00604  |
# |    n_updates        | 7594     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 139      |
# |    ep_rew_mean      | 6.73     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 115      |
# |    time_elapsed     | 273      |
# |    total_timesteps  | 31413    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 7728     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 140      |
# |    ep_rew_mean      | 6.83     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 114      |
# |    time_elapsed     | 277      |
# |    total_timesteps  | 31943    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0465   |
# |    n_updates        | 7860     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 141      |
# |    ep_rew_mean      | 6.98     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 114      |
# |    time_elapsed     | 282      |
# |    total_timesteps  | 32450    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0377   |
# |    n_updates        | 7987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 141      |
# |    ep_rew_mean      | 6.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 114      |
# |    time_elapsed     | 285      |
# |    total_timesteps  | 32832    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0379   |
# |    n_updates        | 8082     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 141      |
# |    ep_rew_mean      | 6.97     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 114      |
# |    time_elapsed     | 290      |
# |    total_timesteps  | 33306    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00234  |
# |    n_updates        | 8201     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 141      |
# |    ep_rew_mean      | 6.97     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 114      |
# |    time_elapsed     | 295      |
# |    total_timesteps  | 33840    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00796  |
# |    n_updates        | 8334     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 140      |
# |    ep_rew_mean      | 6.87     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 114      |
# |    time_elapsed     | 299      |
# |    total_timesteps  | 34306    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0134   |
# |    n_updates        | 8451     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 142      |
# |    ep_rew_mean      | 6.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 114      |
# |    time_elapsed     | 306      |
# |    total_timesteps  | 35062    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0289   |
# |    n_updates        | 8640     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 144      |
# |    ep_rew_mean      | 7.02     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 114      |
# |    time_elapsed     | 313      |
# |    total_timesteps  | 35856    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 8838     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 143      |
# |    ep_rew_mean      | 6.95     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 114      |
# |    time_elapsed     | 319      |
# |    total_timesteps  | 36529    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0051   |
# |    n_updates        | 9007     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 145      |
# |    ep_rew_mean      | 6.97     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 114      |
# |    time_elapsed     | 325      |
# |    total_timesteps  | 37219    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00562  |
# |    n_updates        | 9179     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 145      |
# |    ep_rew_mean      | 7.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 114      |
# |    time_elapsed     | 331      |
# |    total_timesteps  | 37857    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0136   |
# |    n_updates        | 9339     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 144      |
# |    ep_rew_mean      | 6.98     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 114      |
# |    time_elapsed     | 337      |
# |    total_timesteps  | 38550    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00575  |
# |    n_updates        | 9512     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 144      |
# |    ep_rew_mean      | 6.96     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 113      |
# |    time_elapsed     | 342      |
# |    total_timesteps  | 39076    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 9643     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 144      |
# |    ep_rew_mean      | 7.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 113      |
# |    time_elapsed     | 347      |
# |    total_timesteps  | 39573    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 9768     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 143      |
# |    ep_rew_mean      | 6.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 113      |
# |    time_elapsed     | 354      |
# |    total_timesteps  | 40323    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0171   |
# |    n_updates        | 9955     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 145      |
# |    ep_rew_mean      | 7.08     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 113      |
# |    time_elapsed     | 362      |
# |    total_timesteps  | 41180    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00878  |
# |    n_updates        | 10169    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 145      |
# |    ep_rew_mean      | 7.15     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 113      |
# |    time_elapsed     | 367      |
# |    total_timesteps  | 41739    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0268   |
# |    n_updates        | 10309    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 148      |
# |    ep_rew_mean      | 7.36     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 113      |
# |    time_elapsed     | 373      |
# |    total_timesteps  | 42459    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0144   |
# |    n_updates        | 10489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 150      |
# |    ep_rew_mean      | 7.54     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 113      |
# |    time_elapsed     | 379      |
# |    total_timesteps  | 43239    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00472  |
# |    n_updates        | 10684    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | 7.58     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 113      |
# |    time_elapsed     | 385      |
# |    total_timesteps  | 43881    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00579  |
# |    n_updates        | 10845    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 153      |
# |    ep_rew_mean      | 7.67     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 113      |
# |    time_elapsed     | 392      |
# |    total_timesteps  | 44609    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00455  |
# |    n_updates        | 11027    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 157      |
# |    ep_rew_mean      | 7.93     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 113      |
# |    time_elapsed     | 399      |
# |    total_timesteps  | 45433    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0246   |
# |    n_updates        | 11233    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | 8.01     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 113      |
# |    time_elapsed     | 405      |
# |    total_timesteps  | 46059    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00314  |
# |    n_updates        | 11389    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | 8.1      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 113      |
# |    time_elapsed     | 411      |
# |    total_timesteps  | 46771    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0479   |
# |    n_updates        | 11567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 161      |
# |    ep_rew_mean      | 8.23     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 113      |
# |    time_elapsed     | 419      |
# ...
# |    time_elapsed     | 662      |
# |    total_timesteps  | 78403    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00759  |
# |    n_updates        | 19475    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 9.81     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 118      |
# |    time_elapsed     | 670      |
# |    total_timesteps  | 79215    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00669  |
# |    n_updates        | 19678    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 9.8      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 118      |
# |    time_elapsed     | 675      |
# |    total_timesteps  | 79784    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00204  |
# |    n_updates        | 19820    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 9.8      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 118      |
# |    time_elapsed     | 681      |
# |    total_timesteps  | 80482    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.017    |
# |    n_updates        | 19995    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 9.68     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 118      |
# |    time_elapsed     | 687      |
# |    total_timesteps  | 81106    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00887  |
# |    n_updates        | 20151    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 9.71     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 117      |
# |    time_elapsed     | 693      |
# |    total_timesteps  | 81796    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 20323    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 173      |
# |    ep_rew_mean      | 9.64     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 117      |
# |    time_elapsed     | 700      |
# |    total_timesteps  | 82621    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0114   |
# |    n_updates        | 20530    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 9.76     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 117      |
# |    time_elapsed     | 708      |
# |    total_timesteps  | 83549    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 20762    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 174      |
# |    ep_rew_mean      | 9.87     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 117      |
# |    time_elapsed     | 713      |
# |    total_timesteps  | 84156    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00968  |
# |    n_updates        | 20913    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 175      |
# |    ep_rew_mean      | 9.9      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 117      |
# |    time_elapsed     | 719      |
# |    total_timesteps  | 84770    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0311   |
# |    n_updates        | 21067    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 176      |
# |    ep_rew_mean      | 10       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 117      |
# |    time_elapsed     | 726      |
# |    total_timesteps  | 85588    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0188   |
# |    n_updates        | 21271    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 117      |
# |    time_elapsed     | 734      |
# |    total_timesteps  | 86381    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0128   |
# |    n_updates        | 21470    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 117      |
# |    time_elapsed     | 740      |
# |    total_timesteps  | 87130    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0177   |
# |    n_updates        | 21657    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 179      |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 117      |
# |    time_elapsed     | 748      |
# |    total_timesteps  | 87990    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0165   |
# |    n_updates        | 21872    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 117      |
# |    time_elapsed     | 755      |
# |    total_timesteps  | 88765    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 22066    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 117      |
# |    time_elapsed     | 761      |
# |    total_timesteps  | 89356    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.011    |
# |    n_updates        | 22213    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 182      |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 117      |
# |    time_elapsed     | 768      |
# |    total_timesteps  | 90075    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0098   |
# |    n_updates        | 22393    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 183      |
# |    ep_rew_mean      | 10.4     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 612      |
# |    fps              | 117      |
# |    time_elapsed     | 775      |
# |    total_timesteps  | 90859    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0131   |
# |    n_updates        | 22589    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 616      |
# |    fps              | 117      |
# |    time_elapsed     | 780      |
# |    total_timesteps  | 91407    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 22726    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 179      |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 117      |
# |    time_elapsed     | 786      |
# |    total_timesteps  | 92061    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0119   |
# |    n_updates        | 22890    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 181      |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 624      |
# |    fps              | 117      |
# |    time_elapsed     | 793      |
# |    total_timesteps  | 92846    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0174   |
# |    n_updates        | 23086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 628      |
# |    fps              | 117      |
# |    time_elapsed     | 798      |
# |    total_timesteps  | 93533    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0132   |
# |    n_updates        | 23258    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 181      |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 632      |
# |    fps              | 117      |
# |    time_elapsed     | 805      |
# |    total_timesteps  | 94278    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0402   |
# |    n_updates        | 23444    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 181      |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 636      |
# |    fps              | 116      |
# |    time_elapsed     | 812      |
# |    total_timesteps  | 95039    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0103   |
# |    n_updates        | 23634    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 116      |
# |    time_elapsed     | 817      |
# |    total_timesteps  | 95618    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0296   |
# |    n_updates        | 23779    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 644      |
# |    fps              | 116      |
# |    time_elapsed     | 823      |
# |    total_timesteps  | 96228    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0155   |
# |    n_updates        | 23931    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 178      |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 648      |
# |    fps              | 116      |
# |    time_elapsed     | 830      |
# |    total_timesteps  | 97025    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.011    |
# |    n_updates        | 24131    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 179      |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 652      |
# |    fps              | 116      |
# |    time_elapsed     | 836      |
# |    total_timesteps  | 97656    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0236   |
# |    n_updates        | 24288    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 179      |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 656      |
# |    fps              | 116      |
# |    time_elapsed     | 842      |
# |    total_timesteps  | 98335    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0313   |
# |    n_updates        | 24458    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 660      |
# |    fps              | 116      |
# |    time_elapsed     | 849      |
# |    total_timesteps  | 99060    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0169   |
# |    n_updates        | 24639    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 180      |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 664      |
# |    fps              | 116      |
# |    time_elapsed     | 855      |
# |    total_timesteps  | 99770    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0301   |
# |    n_updates        | 24817    |
# ----------------------------------

# %% [markdown]
# ## 6. Test the Model

# %%
# Import eval policy to test agent
from stable_baselines3.common.evaluation import evaluate_policy

# %%
# Reload model from disk
model = DQN.load('./train/dqn/defend_the_center/best_model_100000')

# %%
# Create rendered environment
env = VizDoomGym(render=True)

env.game.set_mode(Mode.ASYNC_PLAYER)

# %%
# Evaluate mean reward for 10 games
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=10)
# Out:
# /home/dayon/Projetos/Intelligent_Agent_DOOM-TCC/.venv/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# /home/dayon/Projetos/Intelligent_Agent_DOOM-TCC/.venv/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %%
mean_reward
# Out:
# np.float64(12.8)

# %%
for episode in range(10):
    obs = env.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        time.sleep(0.20)
        total_reward += reward

    print('Total Reward for episode {} is {}'.format(episode, total_reward))
    time.sleep(2)
# Out:
# Total Reward for episode 0 is 10.0
# Total Reward for episode 1 is 11.0
# Total Reward for episode 2 is 8.0
# Total Reward for episode 3 is 2.0
# Total Reward for episode 4 is 9.0
# Total Reward for episode 5 is 4.0
# Total Reward for episode 6 is 7.0
# Total Reward for episode 7 is 12.0
# Total Reward for episode 8 is 7.0
# Total Reward for episode 9 is 14.0

# %%
env.game.get_state().game_variables
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 env.game.get_state().game_variables
#
# AttributeError: 'NoneType' object has no attribute 'game_variables'

# %%
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=10)
print(f'Mean reward over 100 episodes: {mean_reward}')

# %%
episode_lengths = []
success_count = 0
rewards = []

# Define a success threshold
success_threshold = 12

for episode in range(10):
    obs = env.reset()
    done = False
    total_reward = 0
    steps = 0

    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        total_reward += reward
        steps += 1

    episode_lengths.append(steps)
    rewards.append(total_reward)
    
    # Check if the episode is successful
    if total_reward > success_threshold:
        success_count += 1

avg_episode_length = np.mean(episode_lengths)
success_rate = success_count / 100
reward_variance = np.var(rewards)

print(f'Average Episode Length: {avg_episode_length}')
print(f'Success Rate: {success_rate}')
print(f'Reward Variance (Stability): {reward_variance}')

# %% [markdown]
# ### Import Necessary Libraries for Visualization

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Visualizations!

# %%
# Visualize Episode Length Distribution
plt.figure(figsize=(10, 6))
plt.hist(episode_lengths, bins=10, color='blue', edgecolor='black', label='Episode Lengths')
plt.title('Episode Length Distribution')
plt.xlabel('Number of Steps')
plt.ylabel('Frequency')
plt.legend(loc='upper right')  # Add legend
plt.show()

# %%
# Visualize Reward Distribution
plt.figure(figsize=(10, 6))
plt.hist(rewards, bins=10, color='green', edgecolor='black', label='Rewards')
plt.title('Reward Distribution')
plt.xlabel('Total Reward per Episode')
plt.ylabel('Frequency')
plt.legend(loc='upper right')  # Add legend
plt.show()

# %%
# Visualize Success Rate (Doughnut Chart)
plt.figure(figsize=(6, 6))
labels = ['Success', 'Failure']
sizes = [success_rate * 100, (1 - success_rate) * 100]
colors = ['lightgreen', 'lightcoral']

# Create a doughnut chart
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140, wedgeprops=dict(width=0.3))

# Add a legend
plt.legend(labels, loc='best')

plt.title('Success Rate')
plt.show()

# %%
# Visualize Reward Variance Over Time (Line Chart)
reward_variances = []

for episode in range(100):
    obs = env.reset()
    done = False
    total_reward = 0

    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        total_reward += reward

    rewards.append(total_reward)
    if len(rewards) > 1:
        variance = np.var(rewards)
        reward_variances.append(variance)

# Create a line chart for reward variance
plt.figure(figsize=(10, 6))
plt.plot(reward_variances, color='orange', marker='o', label='Reward Variance')
plt.title('Reward Variance Over Episodes')
plt.xlabel('Episode')
plt.ylabel('Reward Variance (points squared)')
plt.grid(True)
plt.legend(loc='upper right')  # Add legend
plt.show()
